# %% [markdown]
# <a href="https://colab.research.google.com/github/Dstratigou/Askhsh/blob/main/stratigou_ask5_en3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U ppscore

# %%
#εισαγωγή βιβλιοθηκών - πακέτων
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report, confusion_matrix
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#εισαγωγή του συνόλου δεδομένων
dataset=pd.read_csv("https://media.githubusercontent.com/media/kdemertzis/EKPA/main/Data/Ransomware.csv",sep='|')

# %%
#eξερεύνηση συνόλου δεδομένων
dataset
# Out:
#                                                Name  \
# 0                                       memtest.exe
# 1                                           ose.exe
# 2                                         setup.exe
# 3                                          DW20.EXE
# 4                                      dwtrig20.exe
# ...                                             ...
# 138042  VirusShare_8e292b418568d6e7b87f2a32aee7074b
# 138043  VirusShare_260d9e2258aed4c8a3bbd703ec895822
# 138044  VirusShare_8d088a51b7d225c9f5d11d239791ec3f
# 138045  VirusShare_4286dccf67ca220fe67635388229a9f3
# 138046  VirusShare_d7648eae45f09b3adb75127f43be6d11
#
#                                      md5  Machine  SizeOfOptionalHeader  \
# 0       631ea355665f28d4707448e442fbf5b8      332                   224
# 1       9d10f99a6712e28f8acd5641e3a7ea6b      332                   224
# 2       4d92f518527353c0db88a70fddcfd390      332                   224
# ...

# %%
#αφαιρεση της κατηγορηματικής μεταβλητής Name
df = pd.DataFrame(dataset)

newdf = df.drop( "Name" , axis='columns')

print(newdf)
# Out:
#                                      md5  Machine  SizeOfOptionalHeader  \
# 0       631ea355665f28d4707448e442fbf5b8      332                   224
# 1       9d10f99a6712e28f8acd5641e3a7ea6b      332                   224
# 2       4d92f518527353c0db88a70fddcfd390      332                   224
# 3       a41e524f8d45f0074fd07805ff0c9b12      332                   224
# 4       c87e561258f2f8650cef999bf643a731      332                   224
# ...                                  ...      ...                   ...
# 138042  8e292b418568d6e7b87f2a32aee7074b      332                   224
# 138043  260d9e2258aed4c8a3bbd703ec895822      332                   224
# 138044  8d088a51b7d225c9f5d11d239791ec3f      332                   224
# 138045  4286dccf67ca220fe67635388229a9f3      332                   224
# 138046  d7648eae45f09b3adb75127f43be6d11      332                   224
#
#         Characteristics  MajorLinkerVersion  MinorLinkerVersion  SizeOfCode  \
# ...

# %%
#αφαιρεση της κατηγορηματικής μεταβλητής md5
df = pd.DataFrame(newdf)

newdf1 = df.drop( "md5" , axis='columns')

print(newdf1)
# Out:
#         Machine  SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0           332                   224              258                   9
# 1           332                   224             3330                   9
# 2           332                   224             3330                   9
# 3           332                   224              258                   9
# 4           332                   224              258                   9
# ...         ...                   ...              ...                 ...
# 138042      332                   224              258                  11
# 138043      332                   224            33167                   2
# 138044      332                   224              258                  10
# 138045      332                   224            33166                   2
# 138046      332                   224              258                  11
#
#         MinorLinkerVersion  SizeOfCode  SizeOfInitializedData  \
# ...

# %%
# Εκτύπωση καθαρού συνόλου
clean_newdf1
# Out:
#         Machine  SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0           332                   224              258                   9
# 1           332                   224             3330                   9
# 2           332                   224             3330                   9
# 3           332                   224              258                   9
# 4           332                   224              258                   9
# ...         ...                   ...              ...                 ...
# 138042      332                   224              258                  11
# 138043      332                   224            33167                   2
# 138044      332                   224              258                  10
# 138045      332                   224            33166                   2
# 138046      332                   224              258                  11
#
#         MinorLinkerVersion  SizeOfCode  SizeOfInitializedData  \
# ...

# %%
#υπολογισμός του πίνακα pps μεταξύ όλων των στηλών
import ppscore as pps
pps.matrix(newdf1)
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-79-1d3d73acbd9e> in <cell line: 2>()
#       1 #υπολογισμός του πίνακα pps μεταξύ όλων των στηλών
# ----> 2 import ppscore as pps
#       3 pps.matrix(newdf1)
#
# /usr/local/lib/python3.10/dist-packages/ppscore/__init__.py in <module>
#       5     # Change here if project is renamed and does not equal the package name
#       6     dist_name = __name__
# ----> 7     __version__ = get_distribution(dist_name).version
#       8 except DistributionNotFound:  # pragma: no cover
#       9     __version__ = "unknown"
#
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     524         dist = Requirement.parse(dist)
#     525     if isinstance(dist, Requirement):
# --> 526         dist = get_provider(dist)
#     527     if not isinstance(dist, Distribution):
# ...

# %%
import seaborn as sns
predictors_newdf1 = pps.predictors(newdf1, y="y")
sns.barplot(data=predictors_newdf1, x="x", y="ppscore")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-df0617cae720> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 predictors_newdf1 = pps.predictors(newdf1, y="y")
#       3 sns.barplot(data=predictors_newdf1, x="x", y="ppscore")
#
# NameError: name 'pps' is not defined

# %%
import seaborn as sns
matrix_newdf1 = pps.matrix(newdf1)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
sns.heatmap(matrix_newdf1, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-05726230ccc8> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 matrix_newdf1 = pps.matrix(newdf1)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
#       3 sns.heatmap(matrix_newdf1, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)
#
# NameError: name 'pps' is not defined

# %%
# ανακάτεμα δεδομένων
newdf1 = newdf1.sample(frac=1).reset_index(drop=True)
newdf1.head()
# Out:
#    Machine  SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0      332                   224              271                   6
# 1    34404                   240             8226                  10
# 2      332                   224              258                  10
# 3      332                   224              258                  10
# 4      332                   224              271                   8
#
#    MinorLinkerVersion  SizeOfCode  SizeOfInitializedData  \
# 0                   0       23552                 119808
# 1                   0      524800                 363008
# 2                   0      120320                 385024
# 3                   0      118272                 380416
# 4                  10       27648                   9728
#
#    SizeOfUninitializedData  AddressOfEntryPoint  BaseOfCode  ...  ResourcesNb  \
# 0                     1024                12860        4096  ...           11
# ...
